# %% [markdown]
# * Import `pandas` and name as alias `pd`

# %%
import pandas as pd

# %% [markdown]
# * Created a new variable `vegan_restaurants_df` and set it equal to the imported file `vegetarian_restaurants_usa.csv`

# %%
vegan_restaurants_df = pd.read_csv('vegetarian_restaurants_usa.csv')
vegan_restaurants_df.head()
# Out:
#                  address                                         categories  \
# 0  2871 Gulf To Bay Blvd  American, American (new), Clearwater Restauran...
# 1          605 W Main St                             Caf and Sandwich Place
# 2        3803 9th St S W  American, Barbecue, Puyallup Restaurants, Barb...
# 3           30 S Main St  Coffee & Tea, Restaurant, Restaurants, Bar, Am...
# 4         55 Crescent Dr            Sandwich Place and Fast Food Restaurant
#
#             city          claimed country  \
# 0     Clearwater              NaN      US
# 1     Louisville              NaN      US
# 2       Puyallup              NaN      US
# 3        Oberlin              NaN      US
# 4  Pleasant Hill  yellowpages.com      US
#
#                                             cuisines dateOpened  \
# 0                                                NaN        NaN
# 1                          Vegetarian,  Delicatessen        NaN
# ...

# %% [markdown]
# * Renamed `province` column to `state` for clear joining of other .csv files

# %%
vegan_restaurants_df.rename(columns={"province":"state"}, inplace=True)

# %% [markdown]
# * Dropped all unnecessary columns with unwanted data

# %%
dropped_columns_df = vegan_restaurants_df.drop(["key","features","menus","languages","hours","images",
                                                "isClosed","dateOpened","address","categories","claimed", "priceRange",
                                                "dateUpdated", "descriptions","facebookPageURL","menuURL",
                                                "name","paymentTypes","phones" ,"postalCode","sic","twitter",
                                                "websites","cuisines"], axis=1)

# %% [markdown]
# * Cleared all null values in dataframe

# %%
no_null_df = dropped_columns_df.dropna()
no_null_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13669 entries, 0 to 18153
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   city     13669 non-null  object
#  1   country  13669 non-null  object
#  2   lat      13669 non-null  float64
#  3   long     13669 non-null  float64
#  4   state    13669 non-null  object
# dtypes: float64(2), object(3)
# memory usage: 640.7+ KB

# %% [markdown]
# * Sorted values by `city`

# %%
sorted_df = no_null_df.sort_values("city")
sorted_df.head()
# Out:
#             city country        lat       long state
# 4558   Abbeville      US  29.971548 -92.119890    LA
# 4776   Abbeville      US  29.971565 -92.119970    LA
# 8840   Abbeville      US  29.971548 -92.119890    LA
# 657    Abbeville      US  29.971548 -92.119890    LA
# 15680   Aberdeen      US  35.114103 -79.386409    NC

# %% [markdown]
# * * Converted cleaned data frame to `clean_vegetarian_restaurant_locations.csv` file and exported.

# %%
sorted_df.to_csv("clean_vegetarian_restauant_location.csv", encoding="utf-8", index=False)
